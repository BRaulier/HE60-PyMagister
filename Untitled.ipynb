# %% [markdown]
# ## Using HydroLight as basis to tackle heterogeneity

# %%
import scipy.special as sp
import numpy as np
import matplotlib.pyplot as plt

def T_erf(xi_e, alpha_erf):
    T_erf = 1/4 * ( 1 + sp.erf(alpha_erf * xi_e)) + 0.5
    return T_erf


def transmittance_to_kappa(T):
    kappa = np.log(T)/-1 # Assuming a depth of 1 meter
    return kappa

def T_exp(z, kappa):
    T_exp = np.exp(-kappa * z)
    

def 
    


x_dummy = np.linspace(-5, 5, 10000)
exp_T_values = np.array(5000*[0.5] + 5000*[1.0])
y_T_values = T_erf(x_dummy, 0.5)
plt.plot(x_dummy, y_T_values)
plt.show()


plt.hist(y_T_values, bins=30, color='blue', alpha=0.5)
plt.hist(exp_T_values, bins=30, color='red', alpha=0.5)
plt.hist(T_exp(z=, kappa=-np.log(0.5)))
plt.semilogy()
plt.show()

# plt.hist(transmittance_to_kappa(y_T_values), bins=100)
# plt.semilogy()
# plt.show()

# %%
plt.scatter(exp_T_values, y_T_values, marker='.')
plt.plot([0,1], [0,1], linestyle='--', color='lightgray')
plt.show()
